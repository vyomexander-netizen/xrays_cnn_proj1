# %%
print("hello")
# Out:
# hello

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model

# %%
import os
import tensorflow as tf

base_dir = "dataset_split"

test_dir = os.path.join(base_dir, "test")


print("Test exists:", os.path.exists(test_dir))
# Out:
# Test exists: True

# %%
test_data = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(224, 224),
    color_mode="grayscale",
    batch_size=32,
    label_mode="categorical"
)
# Out:
# Found 303 files belonging to 4 classes.

# %%
miguel = tf.keras.models.load_model("hopefull.keras")

# %%
loss, accuracy = miguel.evaluate(test_data)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 4s/step - accuracy: 0.9274 - loss: 0.1758
# Test Loss: 0.17576083540916443
# Test Accuracy: 0.9273927211761475
